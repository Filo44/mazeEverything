# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
array=[
  [ 'DFS 1', 'DFS 2', 'DFSE 1', 'DFSE 2', 'LH 1', 'LH 2' ],
  [ 10.653, 100, 6.9042, 100, 11.61, 100 ],
  [ 10.917, 100, 5.5679, 100, 16.128999999999998, 100 ],
  [ 12.839999999999998, 100, 7.3497, 100, 24.812, 113.78999999999999 ],
  [ 10.725, 100, 8.2405, 100, 12.892000000000001, 94.872 ],
  [ 43.662, 100, 6.9042, 100, 13.420000000000002, 88.571 ],
  [ 21.127000000000002, 100, 3.3408, 100, 19.481, 88.235 ],
  [ 19.481, 100, 3.3408, 100, 22.387999999999998, 100 ],
  [ 14.909, 100, 9.131400000000001, 100, 24.848, 100 ],
  [ 15.337, 100, 5.5679, 100, 17.73, 100 ],
  [ 8.3612, 100, 5.5679, 100, 13.089, 100 ]
]
array20=[
  [ 'DFS 1', 'DFS 2', 'DFSE 1', 'DFSE 2', 'LH 1', 'LH 2' ],
  [ 4.8474, 100, 3.3792000000000004, 100, 9.608500000000001, 100 ],
  [ 7.9365000000000006, 100, 3.1289, 100, 7.837, 100 ],
  [ 4.1591000000000005, 100, 2.8786, 100, 6.784700000000001, 100 ],
  [ 4.7817, 100, 2.8786, 100, 4.4316, 100 ],
  [ 5.2192, 100, 3.1289, 100, 17.007, 100 ],
  [ 5.9181, 100, 4.8811, 100, 19.598, 100 ],
  [ 15.567, 100, 7.384200000000001, 100, 17.302, 100 ],
  [ 11.111, 100, 4.3805, 100, 36.842000000000006, 100 ],
  [ 16.619999999999997, 100, 7.384200000000001, 100, 40.69, 107.27 ],
  [ 6.024100000000001, 100, 3.1289, 100, 4.8356, 92.593 ]
]
array25=[
  [ 'DFS 1', 'DFS 2', 'DFSE 1', 'DFSE 2', 'LH 1', 'LH 2' ],
  [ 2.8054, 100, 2.4819999999999998, 100, 2.9552, 100 ],
  [ 4.6571, 100, 4.4035, 100, 5.032, 100 ],
  [ 33.013999999999996, 100, 5.5244, 100, 53.488, 100 ],
  [ 35.065000000000005, 100, 2.1617, 100, 5.1429, 100 ],
  [ 2.8684000000000003, 100, 2.3219, 100, 2.9866, 100 ],
  [ 4.531700000000001, 100, 3.6029, 100, 23.810000000000002, 100 ],
  [ 33.993, 100, 8.246599999999999, 100, 26.615, 96.262 ],
  [ 6.947399999999999, 100, 2.6421, 100, 7.8014, 100 ],
  [ 6.2426, 100, 4.2434, 100, 6.3779, 100 ],
  [ 6.354500000000001, 100, 4.5637, 100, 8.6495, 100 ]
]
array30=[
  [ 'DFS 1', 'DFS 2', 'DFSE 1', 'DFSE 2', 'LH 1', 'LH 2' ],
  [ 6.9494, 100, 3.2796, 100, 7.5544, 100 ],
  [ 14.285999999999998, 100, 4.7248, 100, 6.2730999999999995, 100 ],
  [ 3.5138000000000003, 100, 2.0566999999999998, 100, 10.137, 100 ],
  [ 5.8824000000000005, 100, 5.2807, 100, 32.423, 97.938 ],
  [ 5.7526, 100, 4.0578, 100, 6.2769, 100 ],
  [ 40.952, 100, 2.3902, 100, 5.263199999999999, 100 ],
  [ 3.7182, 100, 3.1683999999999997, 100, 4.6991, 100 ],
  [ 5.4709, 100, 3.3908, 100, 23.921999999999997, 103.39 ],
  [ 34.94, 100, 4.836, 100, 39.013, 104.82000000000001 ],
  [ 3.1563, 100, 2.279, 100, 3.2773999999999996, 100 ]
]

# %%
df15 = pd.DataFrame(array[1:], columns=array[0])
# df15=df15.drop(columns=["DFS 2","DFSE 2","LH 2"])
df20 = pd.DataFrame(array20[1:], columns=array20[0])
# df20=df20.drop(columns=["DFS 2","DFSE 2","LH 2"])
df25 = pd.DataFrame(array25[1:], columns=array25[0])
# df25=df25.drop(columns=["DFS 2","DFSE 2","LH 2"])
df30 = pd.DataFrame(array30[1:], columns=array30[0])
# df30=df30.drop(columns=["DFS 2","DFSE 2","LH 2"])

# %%
thingy=[[ 'DFS 1', 'DFS 2', 'DFSE 1', 'DFSE 2', 'LH 1', 'LH 2' ]]
total = pd.DataFrame(thingy[1:], columns=thingy[0])
total
# Out:
# Empty DataFrame
# Columns: [DFS 1, DFSE 1, LH 1]
# Index: []

# %%
total.loc[len(total)] = np.array(df15.mean())
total.loc[len(total)] = np.array(df20.mean())
total.loc[len(total)] = np.array(df25.mean())
total.loc[len(total)] = np.array(df30.mean())
total
# Out:
#       DFS 1   DFSE 1      LH 1
# 0  16.80122  6.19153  17.63990
# 1   8.21841  4.25531  16.49364
# 2  13.64791  4.01922  14.28585
# 3  12.46216  3.54640  13.88391

# %%
for column in total.columns:
    plt.plot(total.index, total[column], label=column)

plt.xlabel('Index')
plt.ylabel('Size')
plt.legend()
plt.show()
